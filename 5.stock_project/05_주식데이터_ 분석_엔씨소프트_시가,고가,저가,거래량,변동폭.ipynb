# %%
import torch
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from torch.optim import lr_scheduler
from datetime import datetime, timedelta

# %% [markdown]
# # 주식데이터 불러오기

# %% [markdown]
# ### 종목코드와 링크 생성

# %%
code_df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13', header=0)[0]
code_df.종목코드 = code_df.종목코드.map('{:06d}'.format)

# %%
#상장된 기업들목록에서 회사명과 종목코드만 가져옴
code_df = code_df[['회사명', '종목코드']]
code_df = code_df.rename(columns={'회사명':'name', '종목코드':'code'})
code_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2355 entries, 0 to 2354
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    2355 non-null   object
#  1   code    2355 non-null   object
# dtypes: object(2)
# memory usage: 36.9+ KB

# %%
#회사명을 넣으면, code_df를 뒤져서 종목코드를 찾고, 네이버주식url에 덧대서 출력해주는 함수
def get_url(item_name, code_df):
    code = code_df.query("name=='{}'".format(item_name))['code'].to_string(index=False)
    code = code[1:7]
    url = 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code)
    print("요청 URL = {}".format(url))
    return url

item_name = '엔씨소프트'
url = get_url(item_name, code_df)
# Out:
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=036570

# %% [markdown]
# ### 날짜별 종가, 전일비, 시가, 고가, 저가, 거래량 불러오기

# %%
def convert_col_name_kor_eng(df):  
    df = df.rename(columns= {'날짜': 'date', '종가': 'close', '전일비': 'diff', '시가': 'open', '고가': 'high', '저가': 'low', '거래량': 'volume'}) 
    df[['close', 'diff', 'open', 'high', 'low', 'volume']] = df[['close', 'diff', 'open', 'high', 'low', 'volume']].astype(int) 
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values(by=['date'], ascending=True) 
    df.head()
    return df

def get_dataset(num_date):
    df = pd.DataFrame()
    for page in range(1,num_date+1):
        pg_url = '{url}&page={page}'.format(url=url, page=page)
        df = df.append(pd.read_html(pg_url, header=0)[0], ignore_index=True)
    df = df.dropna()
    df = convert_col_name_kor_eng(df)
    return df

df = get_dataset(493)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4928 entries, 7392 to 1
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    4928 non-null   datetime64[ns]
#  1   close   4928 non-null   int64
#  2   diff    4928 non-null   int64
#  3   open    4928 non-null   int64
#  4   high    4928 non-null   int64
#  5   low     4928 non-null   int64
#  6   volume  4928 non-null   int64
# dtypes: datetime64[ns](1), int64(6)
# memory usage: 308.0 KB

# %% [markdown]
# ### 데이터프레임 -> 넘파이

# %%
df = df.drop(['date'], axis=1)
df_size = len(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4928 entries, 7392 to 1
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   close   4928 non-null   int64
#  1   diff    4928 non-null   int64
#  2   open    4928 non-null   int64
#  3   high    4928 non-null   int64
#  4   low     4928 non-null   int64
#  5   volume  4928 non-null   int64
# dtypes: int64(6)
# memory usage: 269.5 KB

# %%
print(df_size)
# Out:
# 4928

# %%
train_set = df[0:int(df_size*0.7)]
test_set = df[int(df_size*0.7):]

# %%
train = train_set.to_numpy()
test = test_set.to_numpy()

# %%
print(train.shape)
print(test.shape)
print(train[1])
print(train[2])
# Out:
# (3449, 6)
# (1479, 6)
# [87800  9400 87800 87800 87800   206]
# [98300 10500 98300 98300 98300 92439]

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# #### minmax정규화, RNN용 shape으로 변경

# %%
def minmax_scaler(data):
    #print(np.min(data,0))
    numerator = data - np.min(data,0)
    #print(numerator.shape)
    denominator = np.max(data,0) - np.min(data,0)
    #print(numerator.shape)
    return numerator / (denominator + 1e-7)

def build_dataset(time_series, seq_length):
    train_size = int(len(time_series - seq_length))
    dataX = []
    dataY = []

    for i in range(0, len(time_series)-seq_length-1):
        _x = time_series[i:i + seq_length]
        _y = time_series[i + seq_length + 1,[0]]
        dataX.append(_x)
        dataY.append(_y)
        
    return np.array(dataX), np.array(dataY)
#2차원 배열 -> 넘파이배열로 변경시 자료의 사이즈가 맞지 않으면 object타입으로 처리해서 3차원배열로 인식하지 않는다.

# %%
train = minmax_scaler(train)
test_min = np.min(test, 0)
test_max = np.max(test, 0)
test_denom = test_max - test_min
test_minmax = (test-test_min) / (test_denom + 1e-7)#minmax_scaler(test) 

print(train_set.shape)
print(test_set.shape)
# Out:
# (3449, 6)
# (1479, 6)

# %%
seq_length = 7

# %%
trainX, trainY = build_dataset(train, seq_length)
testX, testY = build_dataset(test_minmax, seq_length)
print(trainX.shape, trainY.shape)
print(testX.shape, testY.shape)
# Out:
# (3441, 7, 6) (3441, 1)
# (1471, 7, 6) (1471, 1)

# %% [markdown]
# ### 넘파이 -> 텐서

# %%
class data_loader(Dataset):
    def __init__(self, samples, labels, t):
        self.samples = samples
        self.labels = labels
        self.T = t

    def __getitem__(self, index):
        sample, target = self.samples[index], self.labels[index]
        if self.T:
            return self.T(sample), target
        else:
            return sample, target

    def __len__(self):
        return len(self.samples)

# %%
def load(batch_size):
    transform = None
    train_set = data_loader(trainX, trainY, transform)
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, drop_last=True)
    test_set = data_loader(testX, testY, transform)
    test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)
    return train_loader, test_loader

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # 데이터 출력용 함수들

# %%
def show_train_status(): #학습한 loss 출력
    plt.plot(loss_arr)
    plt.show()
    print(model)
    print(loss_func)
    print(optimizer)
    print('----------------------')
    print('batch_size : ',batch_size)
    print('epoch : ',epoch)

# %% [markdown]
# #### 1. 시가->예측종가기준으로 평가

# %%
def eval_open_to_predict_close(day):    
    day_length = len(predicted_y)
    money = 0
    count_acc = 0
    count_i = 0

    for i in range(day_length-day, day_length):
        count_i = count_i + 1
        #당일 날짜 계산
        today = datetime.today() - timedelta(days=day_length) + timedelta(days=i)
        str_year  = today.strftime('%Y')[:2]
        str_today = str_year + today.strftime('-%m-%d')
        # 투자하면 벌돈 및 실제 벌돈 계산
        expect_money = calculated_predicted_y[i] - calculated_test_x[i]
        earn_money = calculated_test_y[i] - calculated_test_x[i]
        #print(str_today, '시작가\t','\t', '종가\t', '\t', '수익예상')
        #print('예상가\t', calculated_test_x[i],'\t', calculated_predicted_y[i], '\t',expect_money)
        #print('현실가\t', calculated_test_x[i],'\t', calculated_test_y[i], '\t', earn_money)
        # 수익예상이면 투자후 금액 출력
        if (expect_money > 0):
            money = money + earn_money
        #print('번돈\t', money)
        #print('-----------------------------------------------------')
        # 수익 예측을 정확이 했는지 판단.
        if (expect_money >0) & (earn_money >0): count_acc = count_acc + 1
        if (expect_money <0) & (earn_money <0): count_acc = count_acc + 1
    print('----------------------')
    print('시가->예측종가기준')
    print('벌어들인돈 : {0:d}원'.format(int(money)))
    print('정확도 : {0:.3f}%'.format(count_acc/count_i))

# %% [markdown]
# ##### 2.전날예측종가->예측종가기준으로 평가

# %%
def eval_endPredict_to_predict_close(day):    
    day_length = len(predicted_y)
    money = 0
    count_acc = 0
    count_i = 0

    for i in range(day_length-day, day_length-1):
        count_i = count_i + 1
        #당일 날짜 계산
        today = datetime.today() - timedelta(days=day_length) + timedelta(days=i+1)
        str_year  = today.strftime('%Y')[:2]
        str_today = str_year + today.strftime('-%m-%d')
        # 투자하면 벌돈 및 실제 벌돈 계산
        expect_money = calculated_predicted_y[i+1] - calculated_predicted_y[i]
        earn_money = calculated_test_y[i+1] - calculated_test_y[i]
        #print(str_today, '시작가\t','\t', '종가\t', '\t', '수익예상')
        #print('예상가\t', calculated_predicted_y[i],'\t', calculated_predicted_y[i+1], '\t',expect_money)
        #print('현실가\t',calculated_test_y[i],'\t', calculated_test_y[i+1], '\t', earn_money)
        # 수익예상이면 투자후 금액 출력
        if (expect_money > 0):
            money = money + earn_money
        #print('번돈\t', money)
        #print('-----------------------------------------------------')
        # 수익 예측을 정확이 했는지 판단.
        if (expect_money >0) & (earn_money >0): count_acc = count_acc + 1
        if (expect_money <0) & (earn_money <0): count_acc = count_acc + 1
    print('----------------------')
    print('전날예측종가->예측종가')
    print('벌어들인돈 : {0:d}원'.format(int(money)))
    print('정확도 : {0:.3f}%'.format(count_acc/count_i))

# %%
def show_test_graph(day): #환산된 결과 test 그래프
    plt.figure(figsize=(10,5))
    s = len(calculated_predicted_y)
    plt.plot(calculated_predicted_y[s-day:s])
    plt.plot(calculated_test_y[s-day:s])
    plt.legend(['predicted', 'test_y'])
    plt.grid(True)
    plt.xticks([i for i in range(0,day)])
    plt.show()

# %% [markdown]
# # 0.학습 모델 --------------------------------------------

# %%
data_dim = 6
hidden_dim = 10
output_dim = 1

epoch = 200
lr = 0.001
batch_size=2048
layers=1

train_loader, test_loader= load(batch_size=batch_size)
day = 30

# %%
class Net(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, layers):
        super(Net, self).__init__()
        self.rnn = torch.nn.LSTM(input_dim, hidden_dim, num_layers=layers, batch_first=True)
        
        self.fc = torch.nn.Sequential(
            torch.nn.Linear(hidden_dim, output_dim)#, bias=True)
        )
    def forward(self, x):
        x, _status  = self.rnn(x)
        x = self.fc(x[:,-1])
        return x
              
model = Net(data_dim, hidden_dim, output_dim, layers).to(device)

loss_func = torch.nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=lr)
scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, threshold=1, patience=1, mode='min')

loss_arr = []
for i in range(epoch):
    for j, [x, y] in enumerate(train_loader):
        train_x = x.to(device).float()
        train_y = y.to(device).float()
        optimizer.zero_grad()
        outputs = model.forward(train_x)
        
        #print(outputs.shape, train_y.shape)
        #print(outputs.dtype, train_y.dtype)
        
        loss = loss_func(outputs, train_y)
        #이걸 변수명을 같게하면 안되지!
        loss.backward()
        optimizer.step()
        loss_arr.append(loss)
    print(i, loss)
# Out:
# 0 tensor(0.2794, device='cuda:0', grad_fn=<MseLossBackward>)
# 1 tensor(0.2690, device='cuda:0', grad_fn=<MseLossBackward>)
# 2 tensor(0.2758, device='cuda:0', grad_fn=<MseLossBackward>)
# 3 tensor(0.2647, device='cuda:0', grad_fn=<MseLossBackward>)
# 4 tensor(0.2641, device='cuda:0', grad_fn=<MseLossBackward>)
# 5 tensor(0.2567, device='cuda:0', grad_fn=<MseLossBackward>)
# 6 tensor(0.2574, device='cuda:0', grad_fn=<MseLossBackward>)
# 7 tensor(0.2509, device='cuda:0', grad_fn=<MseLossBackward>)
# 8 tensor(0.2351, device='cuda:0', grad_fn=<MseLossBackward>)
# 9 tensor(0.2377, device='cuda:0', grad_fn=<MseLossBackward>)
# 10 tensor(0.2313, device='cuda:0', grad_fn=<MseLossBackward>)
# 96 tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward>)
# 97 tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward>)
# 98 tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward>)
# 99 tensor(0.0076, device='cuda:0', grad_fn=<MseLossBackward>)
# 100 tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward>)
# 101 tensor(0.0073, device='cuda:0', grad_fn=<MseLossBackward>)
# 102 tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward>)
# 103 tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward>)
# 104 tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward>)
# 105 tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward>)
# 106 tensor(0.0064, device='cuda:0', grad_fn=<MseLossBackward>)
# 107 tensor(0.0061, device='cuda:0', grad_fn=<MseLossBackward>)
# 108 tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward>)
# 109 tensor(0.0058, device='cuda:0', grad_fn=<MseLossBackward>)
# 110 tensor(0.0055, device='cuda:0', grad_fn=<MseLossBackward>)
# 111 tensor(0.0057, device='cuda:0', grad_fn=<MseLossBackward>)
# 112 tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward>)
# 113 tensor(0.0052, device='cuda:0', grad_fn=<MseLossBackward>)
# 114 tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward>)
# 115 tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward>)
# 116 tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward>)
# 117 tensor(0.0043, device='cuda:0', grad_fn=<MseLossBackward>)
# 118 tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward>)
# 119 tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward>)
# 120 tensor(0.0038, device='cuda:0', grad_fn=<MseLossBackward>)
# 121 tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward>)
# 122 tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward>)
# 123 tensor(0.0035, device='cuda:0', grad_fn=<MseLossBackward>)
# 124 tensor(0.0035, device='cuda:0', grad_fn=<MseLossBackward>)
# 125 tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward>)
# 126 tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward>)
# 127 tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward>)
# 128 tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward>)
# 129 tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward>)
# 130 tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward>)
# 131 tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)
# 132 tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)
# 133 tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)
# 134 tensor(0.0023, device='cuda:0', grad_fn=<MseLossBackward>)
# 135 tensor(0.0020, device='cuda:0', grad_fn=<MseLossBackward>)
# 136 tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)
# 137 tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)
# 138 tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward>)
# 139 tensor(0.0020, device='cuda:0', grad_fn=<MseLossBackward>)
# 140 tensor(0.0019, device='cuda:0', grad_fn=<MseLossBackward>)
# 141 tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward>)
# 142 tensor(0.0015, device='cuda:0', grad_fn=<MseLossBackward>)
# 143 tensor(0.0016, device='cuda:0', grad_fn=<MseLossBackward>)
# 144 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 145 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 146 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 147 tensor(0.0015, device='cuda:0', grad_fn=<MseLossBackward>)
# 148 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 149 tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)
# 150 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 151 tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)
# 152 tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)
# 153 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 154 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 155 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 156 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 157 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 158 tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)
# 159 tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)
# 160 tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)
# 161 tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)
# 162 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 163 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 164 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 165 tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)
# 166 tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)
# 167 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 168 tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)
# 169 tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)
# 170 tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)
# 171 tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)
# 172 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 173 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 174 tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)
# 175 tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)
# 176 tensor(0.0013, device='cuda:0', grad_fn=<MseLossBackward>)
# 177 tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)
# 178 tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)
# 179 tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)
# 180 tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)
# 181 tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)
# 182 tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)
# 183 tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)
# 184 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 185 tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)
# 186 tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)
# 187 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 188 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 189 tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward>)
# 190 tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)
# 191 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 192 tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward>)
# 193 tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward>)
# 194 tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward>)
# 195 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 196 tensor(0.0012, device='cuda:0', grad_fn=<MseLossBackward>)
# 197 tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)
# 198 tensor(0.0010, device='cuda:0', grad_fn=<MseLossBackward>)
# 199 tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward>)

# %% [markdown]
# # 1.모델 테스트

# %%
testX_tensor = torch.FloatTensor(testX)
testY_tensor = torch.FloatTensor(testY)
loss_ar = []

model.eval()
with torch.no_grad():
    for j, [x, y] in enumerate(test_loader):
        #test_x = x.to(device).float()
        #test_y = y.to(device).float()
        test_x = testX_tensor.to(device).float()
        test_y = testY_tensor.to(device).float()
        predicted = model.forward(test_x)
        loss = loss_func(predicted, test_y)
        
        loss_ar.append(loss)

# %% [markdown]
# # 2.수익

# %% [markdown]
# # 3.Result

# %%
predicted_y = predicted.cpu().numpy()
test_y = testY_tensor.numpy()
test_x = test[7:,2]
calculated_predicted_y = ((predicted_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_y = ((test_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_x = test_x.astype('int')

show_train_status()
eval_open_to_predict_close(day)
eval_endPredict_to_predict_close(day)
show_test_graph(day)
# Out:
# Net(
#   (rnn): LSTM(6, 10, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# MSELoss()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# ----------------------
# batch_size :  64
# epoch :  200
# ----------------------
# 시가->예측종가기준
# 벌어들인돈 : 41000원
# 정확도 : 0.433%
# ----------------------
# 전날예측종가->예측종가
# 벌어들인돈 : 51000원
# 정확도 : 0.414%

# %%
predicted_y = predicted.cpu().numpy()
test_y = testY_tensor.numpy()
test_x = test[7:,2]
calculated_predicted_y = ((predicted_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_y = ((test_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_x = test_x.astype('int')

show_train_status()
eval_open_to_predict_close(day)
eval_endPredict_to_predict_close(day)
show_test_graph(day)
# Out:
# Net(
#   (rnn): LSTM(6, 10, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# MSELoss()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# ----------------------
# batch_size :  128
# epoch :  200
# ----------------------
# 시가->예측종가기준
# 벌어들인돈 : 41000원
# 정확도 : 0.433%
# ----------------------
# 전날예측종가->예측종가
# 벌어들인돈 : 35000원
# 정확도 : 0.345%

# %%
predicted_y = predicted.cpu().numpy()
test_y = testY_tensor.numpy()
test_x = test[7:,2]
calculated_predicted_y = ((predicted_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_y = ((test_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_x = test_x.astype('int')

show_train_status()
eval_open_to_predict_close(day)
eval_endPredict_to_predict_close(day)
show_test_graph(day)
# Out:
# Net(
#   (rnn): LSTM(6, 10, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# MSELoss()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# ----------------------
# batch_size :  256
# epoch :  200
# ----------------------
# 시가->예측종가기준
# 벌어들인돈 : 172000원
# 정확도 : 0.567%
# ----------------------
# 전날예측종가->예측종가
# 벌어들인돈 : 56000원
# 정확도 : 0.448%

# %%
predicted_y = predicted.cpu().numpy()
test_y = testY_tensor.numpy()
test_x = test[7:,2]
calculated_predicted_y = ((predicted_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_y = ((test_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_x = test_x.astype('int')

show_train_status()
eval_open_to_predict_close(day)
eval_endPredict_to_predict_close(day)
show_test_graph(day)
# Out:
# Net(
#   (rnn): LSTM(6, 10, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# MSELoss()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# ----------------------
# batch_size :  512
# epoch :  200
# ----------------------
# 시가->예측종가기준
# 벌어들인돈 : 77000원
# 정확도 : 0.500%
# ----------------------
# 전날예측종가->예측종가
# 벌어들인돈 : 113000원
# 정확도 : 0.483%

# %%
predicted_y = predicted.cpu().numpy()
test_y = testY_tensor.numpy()
test_x = test[7:,2]
calculated_predicted_y = ((predicted_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_y = ((test_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_x = test_x.astype('int')

show_train_status()
eval_open_to_predict_close(day)
eval_endPredict_to_predict_close(day)
show_test_graph(day)
# Out:
# Net(
#   (rnn): LSTM(6, 10, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# MSELoss()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# ----------------------
# batch_size :  1024
# epoch :  200
# ----------------------
# 시가->예측종가기준
# 벌어들인돈 : 220000원
# 정확도 : 0.633%
# ----------------------
# 전날예측종가->예측종가
# 벌어들인돈 : 187000원
# 정확도 : 0.552%

# %%
predicted_y = predicted.cpu().numpy()
test_y = testY_tensor.numpy()
test_x = test[7:,2]
calculated_predicted_y = ((predicted_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_y = ((test_y * (test_denom[0] + 1e-7)) + test_min[0]).astype('int')
calculated_test_x = test_x.astype('int')

show_train_status()
eval_open_to_predict_close(day)
eval_endPredict_to_predict_close(day)
show_test_graph(day)
# Out:
# Net(
#   (rnn): LSTM(6, 10, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# MSELoss()
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.001
#     weight_decay: 0
# )
# ----------------------
# batch_size :  2048
# epoch :  200
# ----------------------
# 시가->예측종가기준
# 벌어들인돈 : 158000원
# 정확도 : 0.533%
# ----------------------
# 전날예측종가->예측종가
# 벌어들인돈 : 84000원
# 정확도 : 0.552%
