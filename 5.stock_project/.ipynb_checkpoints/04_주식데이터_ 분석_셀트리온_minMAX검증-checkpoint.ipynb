# %%
import torch
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# # 주식데이터 불러오기

# %% [markdown]
# ### 종목코드와 링크 생성

# %%
code_df = pd.read_html('http://kind.krx.co.kr/corpgeneral/corpList.do?method=download&searchType=13', header=0)[0]
code_df.종목코드 = code_df.종목코드.map('{:06d}'.format)

# %%
#상장된 기업들목록에서 회사명과 종목코드만 가져옴
code_df = code_df[['회사명', '종목코드']]
code_df = code_df.rename(columns={'회사명':'name', '종목코드':'code'})
code_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    2354 non-null   object
#  1   code    2354 non-null   object
# dtypes: object(2)
# memory usage: 36.9+ KB

# %%
#회사명을 넣으면, code_df를 뒤져서 종목코드를 찾고, 네이버주식url에 덧대서 출력해주는 함수
def get_url(item_name, code_df):
    code = code_df.query("name=='{}'".format(item_name))['code'].to_string(index=False)
    code = code[1:7]
    url = 'http://finance.naver.com/item/sise_day.nhn?code={code}'.format(code=code)
    print("요청 URL = {}".format(url))
    return url

item_name = '셀트리온'
url = get_url(item_name, code_df)
# Out:
# 요청 URL = http://finance.naver.com/item/sise_day.nhn?code=068270

# %% [markdown]
# ### 날짜별 종가, 전일비, 시가, 고가, 저가, 거래량 불러오기

# %%
def convert_col_name_kor_eng(df):  
    df = df.rename(columns= {'날짜': 'date', '종가': 'close', '전일비': 'diff', '시가': 'open', '고가': 'high', '저가': 'low', '거래량': 'volume'}) 
    df[['close', 'diff', 'open', 'high', 'low', 'volume']] = df[['close', 'diff', 'open', 'high', 'low', 'volume']].astype(int) 
    df['date'] = pd.to_datetime(df['date'])
    df = df.sort_values(by=['date'], ascending=True) 
    df.head()
    return df

def get_dataset(num_date):
    df = pd.DataFrame()
    for page in range(1,num_date+1):
        pg_url = '{url}&page={page}'.format(url=url, page=page)
        df = df.append(pd.read_html(pg_url, header=0)[0], ignore_index=True)
    df = df.dropna()
    df = convert_col_name_kor_eng(df)
    return df

df = get_dataset(370)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3693 entries, 5538 to 1
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3693 non-null   datetime64[ns]
#  1   close   3693 non-null   int32
#  2   diff    3693 non-null   int32
#  3   open    3693 non-null   int32
#  4   high    3693 non-null   int32
#  5   low     3693 non-null   int32
#  6   volume  3693 non-null   int32
# dtypes: datetime64[ns](1), int32(6)
# memory usage: 144.3 KB

# %% [markdown]
# ### 데이터프레임 -> 넘파이

# %%
df = df.drop(['date'], axis=1)
df_size = len(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3693 entries, 5538 to 1
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   close   3693 non-null   int32
#  1   diff    3693 non-null   int32
#  2   open    3693 non-null   int32
#  3   high    3693 non-null   int32
#  4   low     3693 non-null   int32
#  5   volume  3693 non-null   int32
# dtypes: int32(6)
# memory usage: 115.4 KB

# %%
print(df_size)
# Out:
# 3693

# %%
train_set = df[0:int(df_size*0.7)]

# %%
test_set = df[int(df_size*0.7):]

# %%
train = train_set.to_numpy()
test = test_set.to_numpy()

# %%
print(train.shape)
print(test.shape)
print(train[1])
print(train[2])
# Out:
# (2585, 6)
# (1108, 6)
# [  6550   1150   7690   7690   6550 422688]
# [  5740    810   6450   6580   5730 182685]

# %% [markdown]
# # 데이터 전처리

# %% [markdown]
# #### minmax정규화, RNN용 shape으로 변경

# %%
def minmax_scaler(data):
    print(np.min(data,0))
    numerator = data - np.min(data,0)
    print(numerator.shape)
    denominator = np.max(data,0) - np.min(data,0)
    print(numerator.shape)
    return numerator / (denominator + 1e-7)

def build_dataset(time_series, seq_length):
    train_size = int(len(time_series - seq_length))
    dataX = []
    dataY = []

    for i in range(0, len(time_series)-seq_length):
        _x = time_series[i:i + seq_length,1:]
        _y = time_series[i + seq_length,[0]]
        dataX.append(_x)
        dataY.append(_y)
        
    return np.array(dataX), np.array(dataY)
#2차원 배열 -> 넘파이배열로 변경시 자료의 사이즈가 맞지 않으면 object타입으로 처리해서 3차원배열로 인식하지 않는다.

# %%
train = minmax_scaler(train)
test_min = np.min(test, 0)
test_max = np.max(test, 0)
test_denom = test_max - test_min
test_minmax = (test-test_min) / (test_denom + 1e-7)#minmax_scaler(test) 
print(train_set.shape)
print(test_set.shape)
# Out:
# [2270    0    0    0    0    0]
# [[  5430   2500   6700   7700   6510 499088]
#  [  4280   1150   7690   7690   6550 422688]
#  [  3470    810   6450   6580   5730 182685]
#  ...
#  [ 78330    100  80600  82100  80100 804042]
#  [ 76330   2000  79700  80500  78300 727665]
#  [ 75930    400  77300  79300  76100 601871]]
# [   90030    11300    92300    97400    89700 26083474]
# (2585, 6)
# (1108, 6)

# %%
print(test_min)
# Out:
# [ 76700      0  77900  78600  76300 160767]

# %%
seq_length = 7

# %%
trainX, trainY = build_dataset(train, seq_length)
testX, testY = build_dataset(test_minmax, seq_length)
print(trainX.shape, trainY.shape)
print(testX.shape, testY.shape)
# Out:
# (2578, 7, 5) (2578, 1)
# (1101, 7, 5) (1101, 1)

# %% [markdown]
# ### 넘파이 -> 텐서

# %%
class data_loader(Dataset):
    def __init__(self, samples, labels, t):
        self.samples = samples
        self.labels = labels
        self.T = t

    def __getitem__(self, index):
        sample, target = self.samples[index], self.labels[index]
        if self.T:
            return self.T(sample), target
        else:
            return sample, target

    def __len__(self):
        return len(self.samples)

# %%
def load(batch_size):
    transform = None
    train_set = data_loader(trainX, trainY, transform)
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, drop_last=True)
    test_set = data_loader(testX, testY, transform)
    test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)
    return train_loader, test_loader

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # 학습 모델

# %%
data_dim = 5
hidden_dim = 100
output_dim = 1
lr = 0.0001
epoch = 100

batch_size=512
layers=4

# %%
train_loader, test_loader= load(batch_size=batch_size)

# %%
class Net(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, layers):
        super(Net, self).__init__()
        self.rnn = torch.nn.LSTM(input_dim, hidden_dim, num_layers=layers, batch_first=True)
        
        self.fc = torch.nn.Sequential(
            torch.nn.Linear(hidden_dim, 25),# bias=True),
            torch.nn.ReLU(),
            torch.nn.Linear(25, output_dim)#, bias=True)
        )
    def forward(self, x):
        x, _status  = self.rnn(x)
        x = self.fc(x[:,-1])
        return x
              
model = Net(data_dim, hidden_dim, output_dim, layers).to(device)

# %%
loss_func = torch.nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=lr)

# %%
loss_arr = []
for i in range(epoch):
    for j, [x, y] in enumerate(train_loader):
        train_x = x.to(device).float()
        train_y = y.to(device).float()
        optimizer.zero_grad()
        outputs = model.forward(train_x)
        
        #print(outputs.shape, train_y.shape)
        #print(outputs.dtype, train_y.dtype)
        
        loss = loss_func(outputs, train_y)
        #이걸 변수명을 같게하면 안되지!
        loss.backward()
        optimizer.step()
        loss_arr.append(loss)
    print(i, loss)
# Out:
# 0 tensor(0.1338, device='cuda:0', grad_fn=<MseLossBackward>)
# 1 tensor(0.1168, device='cuda:0', grad_fn=<MseLossBackward>)
# 2 tensor(0.1280, device='cuda:0', grad_fn=<MseLossBackward>)
# 3 tensor(0.1137, device='cuda:0', grad_fn=<MseLossBackward>)
# 4 tensor(0.1094, device='cuda:0', grad_fn=<MseLossBackward>)
# 5 tensor(0.1093, device='cuda:0', grad_fn=<MseLossBackward>)
# 6 tensor(0.1036, device='cuda:0', grad_fn=<MseLossBackward>)
# 7 tensor(0.0905, device='cuda:0', grad_fn=<MseLossBackward>)
# 8 tensor(0.0812, device='cuda:0', grad_fn=<MseLossBackward>)
# 9 tensor(0.0800, device='cuda:0', grad_fn=<MseLossBackward>)
# 10 tensor(0.0787, device='cuda:0', grad_fn=<MseLossBackward>)
# 11 tensor(0.0703, device='cuda:0', grad_fn=<MseLossBackward>)
# 12 tensor(0.0676, device='cuda:0', grad_fn=<MseLossBackward>)
# 13 tensor(0.0492, device='cuda:0', grad_fn=<MseLossBackward>)
# 14 tensor(0.0493, device='cuda:0', grad_fn=<MseLossBackward>)
# 15 tensor(0.0484, device='cuda:0', grad_fn=<MseLossBackward>)
# 16 tensor(0.0448, device='cuda:0', grad_fn=<MseLossBackward>)
# 17 tensor(0.0455, device='cuda:0', grad_fn=<MseLossBackward>)
# 18 tensor(0.0415, device='cuda:0', grad_fn=<MseLossBackward>)
# 19 tensor(0.0411, device='cuda:0', grad_fn=<MseLossBackward>)
# 20 tensor(0.0349, device='cuda:0', grad_fn=<MseLossBackward>)
# 21 tensor(0.0358, device='cuda:0', grad_fn=<MseLossBackward>)
# 22 tensor(0.0331, device='cuda:0', grad_fn=<MseLossBackward>)
# 23 tensor(0.0276, device='cuda:0', grad_fn=<MseLossBackward>)
# 24 tensor(0.0235, device='cuda:0', grad_fn=<MseLossBackward>)
# 25 tensor(0.0179, device='cuda:0', grad_fn=<MseLossBackward>)
# 26 tensor(0.0130, device='cuda:0', grad_fn=<MseLossBackward>)
# 27 tensor(0.0097, device='cuda:0', grad_fn=<MseLossBackward>)
# 28 tensor(0.0070, device='cuda:0', grad_fn=<MseLossBackward>)
# 29 tensor(0.0062, device='cuda:0', grad_fn=<MseLossBackward>)
# 30 tensor(0.0051, device='cuda:0', grad_fn=<MseLossBackward>)
# 31 tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward>)
# 32 tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward>)
# 33 tensor(0.0045, device='cuda:0', grad_fn=<MseLossBackward>)
# 34 tensor(0.0032, device='cuda:0', grad_fn=<MseLossBackward>)
# 35 tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward>)
# 36 tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward>)
# 37 tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)
# 38 tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward>)
# 39 tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward>)
# 40 tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward>)
# 41 tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward>)
# 42 tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)
# 43 tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)
# 44 tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)
# 45 tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward>)
# 46 tensor(0.0020, device='cuda:0', grad_fn=<MseLossBackward>)
# 47 tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward>)
# 48 tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)
# 49 tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)
# 50 tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)
# 51 tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)
# 52 tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)
# 53 tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward>)
# 54 tensor(0.0022, device='cuda:0', grad_fn=<MseLossBackward>)
# 55 tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)
# 56 tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)
# 57 tensor(0.0030, device='cuda:0', grad_fn=<MseLossBackward>)
# 58 tensor(0.0022, device='cuda:0', grad_fn=<MseLossBackward>)
# 59 tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward>)
# 60 tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)
# 61 tensor(0.0020, device='cuda:0', grad_fn=<MseLossBackward>)
# 62 tensor(0.0029, device='cuda:0', grad_fn=<MseLossBackward>)
# 63 tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward>)
# 64 tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)
# 65 tensor(0.0020, device='cuda:0', grad_fn=<MseLossBackward>)
# 66 tensor(0.0024, device='cuda:0', grad_fn=<MseLossBackward>)
# 67 tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)
# 68 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 69 tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)
# 70 tensor(0.0023, device='cuda:0', grad_fn=<MseLossBackward>)
# 71 tensor(0.0016, device='cuda:0', grad_fn=<MseLossBackward>)
# 72 tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward>)
# 73 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 74 tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)
# 75 tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)
# 76 tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward>)
# 77 tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)
# 78 tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)
# 79 tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)
# 80 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 81 tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward>)
# 82 tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)
# 83 tensor(0.0017, device='cuda:0', grad_fn=<MseLossBackward>)
# 84 tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)
# 85 tensor(0.0028, device='cuda:0', grad_fn=<MseLossBackward>)
# 86 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 87 tensor(0.0025, device='cuda:0', grad_fn=<MseLossBackward>)
# 88 tensor(0.0019, device='cuda:0', grad_fn=<MseLossBackward>)
# 89 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 90 tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward>)
# 91 tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward>)
# 92 tensor(0.0016, device='cuda:0', grad_fn=<MseLossBackward>)
# 93 tensor(0.0023, device='cuda:0', grad_fn=<MseLossBackward>)
# 94 tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)
# 95 tensor(0.0019, device='cuda:0', grad_fn=<MseLossBackward>)
# 96 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 97 tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward>)
# 98 tensor(0.0021, device='cuda:0', grad_fn=<MseLossBackward>)
# 99 tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward>)

# %%
plt.plot(loss_arr)
plt.show()

# %% [markdown]
# ## 모델 테스트

# %%
testX_tensor = torch.FloatTensor(testX)
testY_tensor = torch.FloatTensor(testY)

# %%
correct = 0
total = 0
loss_arr = []

model.eval()
with torch.no_grad():
    for j, [x, y] in enumerate(test_loader):
        #test_x = x.to(device).float()
        #test_y = y.to(device).float()
        test_x = testX_tensor.to(device).float()
        test_y = testY_tensor.to(device).float()
        predicted = model.forward(test_x)
        loss = loss_func(predicted, test_y)
        
        total += y.size(0)
        #print(y.shape, predicted.shape)
        #print(y, predicted)
        loss_arr.append(loss)
        #print(i, loss)
    # 테스트 데이터 전체에 대해 위의 작업을 시행한 후 정확도를 구해줍니다.
    #print("Accuracy of Test Data: {}%".format(float(correct) * 100 / total))

# %%
def show_result_graph(): 
    print(model)
    print('batch_size :',batch_size, ' layers: ', layers)
    plt.figure(figsize=(30,10))
    plt.plot(predicted.cpu())
    plt.plot(test_y.cpu())
    plt.legend(['predicted', 'test_y'])
    plt.grid(True)
    #plt.xticks([20*i for i in range(0,46)])
    plt.show()

# %%
show_result_graph()
# Out:
# Net(
#   (rnn): LSTM(5, 100, num_layers=4, batch_first=True)
#   (fc): Sequential(
#     (0): Linear(in_features=100, out_features=25, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=25, out_features=1, bias=True)
#   )
# )
# batch_size : 512  layers:  4

# %% [markdown]
# ### 실제데이터 값으로 변환

# %%
predicted_y = predicted.cpu().numpy()#.astype('int')
test_y = testY#.astype('int')
test_x = testX
calculated_predicted_y = (predicted_y * (test_denom[0] + 1e-7)) + test_min[0]
calculated_test_y = (test_y * (test_denom[0] + 1e-7)) + test_min[0]
calculated_predicted_y = calculated_predicted_y.astype('int')
calculated_test_y = calculated_test_y.astype('int')

# %%
from datetime import datetime, timedelta
today = datetime.today() - timedelta(days=1)
str_day = today.strftime('%Y-%m-%d')
print(str_today)
# Out:
# 06-21

# %%
day_length = len(predicted_y)
money = 0
count_acc = 0

for i in range(day_length-11, day_length-1):
    #당일 날짜 계산
    today = datetime.today() - timedelta(days=day_length) + timedelta(days=i)
    str_year  = today.strftime('%Y')
    str_today = today.strftime('%m-%d')
    # 투자하면 벌돈 및 실제 벌돈 계산
    expect_money = calculated_predicted_y[i+1] - calculated_predicted_y[i]
    earn_money = calculated_test_y[i+1] - calculated_test_y[i]
    print(str_year, '\t', '시작가\t','\t', '종가\t', '\t', '수익예상')
    print(str_today,'\t', calculated_predicted_y[i],'\t', calculated_predicted_y[i+1], '\t',expect_money)
    print('\t', calculated_test_y[i],'\t', calculated_test_y[i+1], '\t', earn_money)
    # 수익예상이면 투자후 금액 출력
    if (expect_money > 0):
        money = money + earn_money
    print('now:\t', money)
    print('-----------------------------------------------------')
    # 수익 예측을 정확이 했는지 판단.
    if (expect_money >0) & (earn_money >0): count_acc = count_acc + 1
    if (expect_money <0) & (earn_money <0): count_acc = count_acc + 1
# Out:
# 2020 	 시작가	 	 종가	 	 수익예상
# 06-13 	 [224123] 	 [232663] 	 [8540]
# 	 [263500] 	 [268500] 	 [5000]
# now:	 [5000]
# -----------------------------------------------------
# 2020 	 시작가	 	 종가	 	 수익예상
# 06-14 	 [232663] 	 [239024] 	 [6361]
# 	 [268500] 	 [288000] 	 [19500]
# now:	 [24500]
# -----------------------------------------------------
# 2020 	 시작가	 	 종가	 	 수익예상
# 06-15 	 [239024] 	 [246752] 	 [7728]
# 	 [288000] 	 [297500] 	 [9500]
# now:	 [34000]
# -----------------------------------------------------
# 2020 	 시작가	 	 종가	 	 수익예상
# 06-16 	 [246752] 	 [256039] 	 [9287]
# 	 [297500] 	 [274000] 	 [-23500]
# now:	 [10500]
# -----------------------------------------------------
# 2020 	 시작가	 	 종가	 	 수익예상
# 06-17 	 [256039] 	 [263811] 	 [7772]
# 	 [274000] 	 [293500] 	 [19500]
# now:	 [30000]
# -----------------------------------------------------
# 2020 	 시작가	 	 종가	 	 수익예상
# 06-18 	 [263811] 	 [271097] 	 [7286]
# 	 [293500] 	 [289500] 	 [-4000]
# now:	 [26000]
# -----------------------------------------------------
# 2020 	 시작가	 	 종가	 	 수익예상
# 06-19 	 [271097] 	 [278951] 	 [7854]
# 	 [289500] 	 [287500] 	 [-2000]
# now:	 [24000]
# -----------------------------------------------------
# 2020 	 시작가	 	 종가	 	 수익예상
# 06-20 	 [278951] 	 [287115] 	 [8164]
# 	 [287500] 	 [291500] 	 [4000]
# now:	 [28000]
# -----------------------------------------------------
# 2020 	 시작가	 	 종가	 	 수익예상
# 06-21 	 [287115] 	 [294540] 	 [7425]
# 	 [291500] 	 [297000] 	 [5500]
# now:	 [33500]
# -----------------------------------------------------
# 2020 	 시작가	 	 종가	 	 수익예상
# 06-22 	 [294540] 	 [294400] 	 [-140]
# 	 [297000] 	 [318500] 	 [21500]
# now:	 [33500]
# -----------------------------------------------------

# %%
print('벌어들인돈 : {0:d}원'.format(int(money)))
print('정확도 : {0:.3f}%'.format(count_acc/10))
# Out:
# 벌어들인돈 : 33500원
# 정확도 : 0.600%

# %%
len(predicted_y)
# Out:
# 1101

# %% [markdown]
# ## MinMAX검증 방법

# %%
test_min_ = np.min(test,0)[0]
test_max_ = np.max(test,0)[0]
test_denom_ = test_max_-test_min_

print(test_min_)
print(test_max_)
print(test_denom_)

print(test[:,0].shape)
print('----------')
print(test_min_.shape)
print(test_max_.shape)
print(test_denom_.shape)
print('----------')
test_mm = (test[:,0] -test_min_)/ (test_denom_ + 1e-7)


print((test_denom[0] + 1e-7).shape)
print(test_mm.shape)
print(test_y.reshape(-1,).shape)

calculated_mm_y = (test_mm * (test_denom_ + 1e-7)) + test_min_
calculated_test_y  = (test_y.reshape(-1,) * (test_denom_ + 1e-7)) + test_min_
print('----------')
print(calculated_mm_y.shape)
print(calculated_test_y.shape)
#print(calculated_y.astype('int'))
# Out:
# 76700
# 373500
# 296800
# (1108,)
# ----------
# ()
# ()
# ()
# ----------
# ()
# (1108,)
# (1101,)
# ----------
# (1108,)
# (1101,)

# %%
test_mm
# Out:
# array([0.00876011, 0.01145553, 0.01212938, ..., 0.72371968, 0.74225067,
#        0.81469003])

# %%
test_y.reshape(-1,)
# Out:
# array([0.00673854, 0.        , 0.02459569, ..., 0.72371968, 0.74225067,
#        0.81469003])

# %%
calculated_mm_y[1091:1101]
# Out:
# array([227500., 224500., 227500., 247000., 256500., 256000., 263500.,
#        268500., 288000., 297500.])

# %%
calculated_test_y[1091:1101]
# Out:
# array([268500., 288000., 297500., 274000., 293500., 289500., 287500.,
#        291500., 297000., 318500.])

# %%
print(test[1091:1101])
# Out:
# [[ 227500   14000  214000  232500  213000 3410255]
#  [ 224500    3000  230000  232500  222000 1115810]
#  [ 227500    3000  231500  235000  224500 1813508]
#  [ 247000   19500  227500  248000  227000 3037387]
#  [ 256500    9500  244000  260500  243000 2899453]
#  [ 256000     500  260500  263000  253000 1267019]
#  [ 263500    7500  257000  264500  255000 1345656]
#  [ 268500    5000  263500  270000  261500 1067682]
#  [ 288000   19500  280000  299500  274500 3934710]
#  [ 297500    9500  280000  303500  279000 3865779]]

# %%
# %matplotlib inline
plt.figure(figsize=(30,15))
plt.plot(calculated_predicted_y)
plt.plot(calculated_test_y)
plt.legend(['predicted', 'test_y'])
plt.grid(True)
#plt.xticks([20*i for i in range(0,46)])
plt.show()

# %%
# Out:
# '06-23'
